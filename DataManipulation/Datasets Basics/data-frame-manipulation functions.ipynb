# %%
import numpy as np
import pandas as pd
import os

os.getcwd()
# Out:
# 'C:\\Users\\shaik\\OneDrive\\Desktop\\Python Programming\\DataManipulation\\Datasets Basics'

# %%
#import datafiles
AB_NYC = 'C:\\Users\\shaik\\OneDrive\\Desktop\\Python Programming\\DataManipulation\\Kaggle-Data-Sets\\AB_NYC_2019.csv'
df = pd.read_csv(AB_NYC)
df.head(3)
# Out:
#      id                                 name  host_id  host_name  \
# 0  2539   Clean & quiet apt home by the park     2787       John
# 1  2595                Skylit Midtown Castle     2845   Jennifer
# 2  3647  THE VILLAGE OF HARLEM....NEW YORK !     4632  Elisabeth
#
#   neighbourhood_group neighbourhood  latitude  longitude        room_type  \
# 0            Brooklyn    Kensington  40.64749  -73.97237     Private room
# 1           Manhattan       Midtown  40.75362  -73.98377  Entire home/apt
# 2           Manhattan        Harlem  40.80902  -73.94190     Private room
#
#    price  minimum_nights  number_of_reviews last_review  reviews_per_month  \
# 0    149               1                  9  2018-10-19               0.21
# 1    225               1                 45  2019-05-21               0.38
# 2    150               3                  0         NaN                NaN
#
#    calculated_host_listings_count  availability_365
# ...

# %% [markdown]
# ## Indexing
# Indexing in pandas means simply selecting particular rows and columns of data from a DataFrame. Indexing could mean selecting all the rows and some of the columns, some of the rows and all of the columns, or some of each of the rows and columns. Indexing can also be known as Subset Selection.

# %%
df2 = df.set_index('id')
df2.head(3)
# Out:
#                                      name  host_id  host_name  \
# id
# 2539   Clean & quiet apt home by the park     2787       John
# 2595                Skylit Midtown Castle     2845   Jennifer
# 3647  THE VILLAGE OF HARLEM....NEW YORK !     4632  Elisabeth
#
#      neighbourhood_group neighbourhood  latitude  longitude        room_type  \
# id
# 2539            Brooklyn    Kensington  40.64749  -73.97237     Private room
# 2595           Manhattan       Midtown  40.75362  -73.98377  Entire home/apt
# 3647           Manhattan        Harlem  40.80902  -73.94190     Private room
#
#       price  minimum_nights  number_of_reviews last_review  reviews_per_month  \
# id
# 2539    149               1                  9  2018-10-19               0.21
# 2595    225               1                 45  2019-05-21               0.38
# 3647    150               3                  0         NaN                NaN
#
#       calculated_host_listings_count  availability_365
# id
# ...

# %%
df2.name[2539]
df2.host_name[3647]
# Out:
# 'Elisabeth'

# %%
df3= df.groupby('room_type').mean()
df3
#Reseting Index on room_type column
df3.reset_index()
# Out:
#          room_type            id       host_id   latitude  longitude  \
# 0  Entire home/apt  1.843818e+07  6.175593e+07  40.728649 -73.960696
# 1     Private room  1.946893e+07  7.247514e+07  40.729208 -73.942924
# 2      Shared room  2.300378e+07  1.026241e+08  40.730514 -73.943343
#
#         price  minimum_nights  number_of_reviews  reviews_per_month  \
# 0  211.794246        8.506907          22.842418           1.306578
# 1   89.780973        5.377900          24.112962           1.445209
# 2   70.127586        6.475000          16.600000           1.471726
#
#    calculated_host_listings_count  availability_365
# 0                       10.698335        111.920304
# 1                        3.227717        111.203933
# 2                        4.662931        162.000862

# %%
df3.reset_index(drop=True)
# Out:
#              id       host_id   latitude  longitude       price  \
# 0  1.843818e+07  6.175593e+07  40.728649 -73.960696  211.794246
# 1  1.946893e+07  7.247514e+07  40.729208 -73.942924   89.780973
# 2  2.300378e+07  1.026241e+08  40.730514 -73.943343   70.127586
#
#    minimum_nights  number_of_reviews  reviews_per_month  \
# 0        8.506907          22.842418           1.306578
# 1        5.377900          24.112962           1.445209
# 2        6.475000          16.600000           1.471726
#
#    calculated_host_listings_count  availability_365
# 0                       10.698335        111.920304
# 1                        3.227717        111.203933
# 2                        4.662931        162.000862

# %% [markdown]
# ## Sorting
# * sort_index()
# * sort_values()

# %%
df.sort_index(ascending = False).head(3)
# Out:
#              id                                               name   host_id  \
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
#
#            host_name neighbourhood_group   neighbourhood  latitude  longitude  \
# 48894     Christophe           Manhattan  Hell's Kitchen  40.76404  -73.98933
# 48893            Taz           Manhattan  Hell's Kitchen  40.75751  -73.99112
# 48892  Ilgar & Aysel           Manhattan          Harlem  40.81475  -73.94867
#
#              room_type  price  minimum_nights  number_of_reviews last_review  \
# 48894     Private room     90               7                  0         NaN
# 48893      Shared room     55               1                  0         NaN
# 48892  Entire home/apt    115              10                  0         NaN
#
# ...

# %%
df.sort_values(['neighbourhood_group','host_name'],ascending=[False,True]).head(3)
#toreset dataset user inplace parameter as True
# Out:
#              id                                         name   host_id  \
# 4079    2611458           close to Manhattan country setting  13373889
# 16714  13370393                                    Charming.  13373889
# 24922  19970350  Newly renovated clean and Cozy Private room  15344412
#
#       host_name neighbourhood_group    neighbourhood  latitude  longitude  \
# 4079      Aaron       Staten Island          Concord  40.60375  -74.08065
# 16714     Aaron       Staten Island          Concord  40.60556  -74.08274
# 24922       Abe       Staten Island  New Springville  40.58085  -74.15443
#
#              room_type  price  minimum_nights  number_of_reviews last_review  \
# 4079      Private room    129               1                 40  2018-10-14
# 16714  Entire home/apt    150               7                  1  2018-11-04
# 24922     Private room     43              10                  0         NaN
#
# ...

# %% [markdown]
# ## Rank
# Rank is like soft but collision detection

# %%
dfp = df.sort_values('price',ascending=False)
dfp[['name','host_id','price']].head()
# Out:
#                                                     name   host_id  price
# 9151                 Furnished room in Astoria apartment  20582832  10000
# 17692    Luxury 1 bedroom apt. -stunning Manhattan views   5143901  10000
# 29238                                1-BR Lincoln Center  72390391  10000
# 40433  2br - The Heart of NYC: Manhattans Lower East ...   4382127   9999
# 12342                Quiet, Clean, Lit @ LES & Chinatown   3906464   9999

# %%
dfp['price_rank'] = dfp.price.rank(method='average',ascending=False)

# %%
dfp[['name','host_id','price','price_rank']].head()
# Out:
#                                                     name   host_id  price  \
# 9151                 Furnished room in Astoria apartment  20582832  10000
# 17692    Luxury 1 bedroom apt. -stunning Manhattan views   5143901  10000
# 29238                                1-BR Lincoln Center  72390391  10000
# 40433  2br - The Heart of NYC: Manhattans Lower East ...   4382127   9999
# 12342                Quiet, Clean, Lit @ LES & Chinatown   3906464   9999
#
#        price_rank
# 9151          2.0
# 17692         2.0
# 29238         2.0
# 40433         5.0
# 12342         5.0

# %%
host_name = df.host_name.unique()
hostname_count = df.host_name.value_counts()
print(hostname_count)
# Out:
# Michael         417
# David           403
# Sonder (NYC)    327
# John            294
# Alex            279
#                ...
# Funmilade         1
# Mariame           1
# Minetta           1
# Sanjeev           1
# Am                1
# Name: host_name, Length: 11452, dtype: int64

# %% [markdown]
# ## Recap
# * set_index()
# * reset_index()
# * Sort_index()
# * soft_values()
# * unique()
# * value_count()
# * rank()

# %% [markdown]
# ## Slicing
# 1. rows

# %%
df.price.head()
df['price'].head()

#Multiple columns
df[['host_name','host_id']].head()
# Out:
#      host_name  host_id
# 0         John     2787
# 1     Jennifer     2845
# 2    Elisabeth     4632
# 3  LisaRoxanne     4869
# 4        Laura     7192

# %% [markdown]
# **Filtering on rows**

# %%
df.host_name == 'John'
# Out:
# 0         True
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 48890    False
# 48891    False
# 48892    False
# 48893    False
# 48894    False
# Name: host_name, Length: 48895, dtype: bool

# %%
mask = df.host_name == 'Tazz'

# %%
df[mask]
# Out:
# Empty DataFrame
# Columns: [id, name, host_id, host_name, neighbourhood_group, neighbourhood, latitude, longitude, room_type, price, minimum_nights, number_of_reviews, last_review, reviews_per_month, calculated_host_listings_count, availability_365]
# Index: []

# %%
quick_and_cheap = (df.price < 300) & (df.minimum_nights < 3)
quick_and_cheap.count()
# Out:
# 48895

# %%
df[quick_and_cheap].head(2)
# Out:
#      id                                name  host_id host_name  \
# 0  2539  Clean & quiet apt home by the park     2787      John
# 1  2595               Skylit Midtown Castle     2845  Jennifer
#
#   neighbourhood_group neighbourhood  latitude  longitude        room_type  \
# 0            Brooklyn    Kensington  40.64749  -73.97237     Private room
# 1           Manhattan       Midtown  40.75362  -73.98377  Entire home/apt
#
#    price  minimum_nights  number_of_reviews last_review  reviews_per_month  \
# 0    149               1                  9  2018-10-19               0.21
# 1    225               1                 45  2019-05-21               0.38
#
#    calculated_host_listings_count  availability_365
# 0                               6               365
# 1                               2               355

# %%
reviews_consistent = df[(df.reviews_per_month > 3) | (df.number_of_reviews > 50)]
reviews_consistent.head(2)
# Out:
#      id                                       name  host_id    host_name  \
# 3  3831            Cozy Entire Floor of Brownstone     4869  LisaRoxanne
# 5  5099  Large Cozy 1 BR Apartment In Midtown East     7322        Chris
#
#   neighbourhood_group neighbourhood  latitude  longitude        room_type  \
# 3            Brooklyn  Clinton Hill  40.68514  -73.95976  Entire home/apt
# 5           Manhattan   Murray Hill  40.74767  -73.97500  Entire home/apt
#
#    price  minimum_nights  number_of_reviews last_review  reviews_per_month  \
# 3     89               1                270  2019-07-05               4.64
# 5    200               3                 74  2019-06-22               0.59
#
#    calculated_host_listings_count  availability_365
# 3                               1               194
# 5                               1               129

# %%
mask = np.logical_or((df.reviews_per_month > 3),(df.number_of_reviews > 50))

# %%
df[mask].count()
# Out:
# id                                9588
# name                              9588
# host_id                           9588
# host_name                         9582
# neighbourhood_group               9588
# neighbourhood                     9588
# latitude                          9588
# longitude                         9588
# room_type                         9588
# price                             9588
# minimum_nights                    9588
# number_of_reviews                 9588
# last_review                       9588
# reviews_per_month                 9588
# calculated_host_listings_count    9588
# availability_365                  9588
# dtype: int64

# %%
#'~' Logical inversion True becomes False and False become True.

# %%
df[~mask].count()
# Out:
# id                                39307
# name                              39291
# host_id                           39307
# host_name                         39292
# neighbourhood_group               39307
# neighbourhood                     39307
# latitude                          39307
# longitude                         39307
# room_type                         39307
# price                             39307
# minimum_nights                    39307
# number_of_reviews                 39307
# last_review                       29255
# reviews_per_month                 29255
# calculated_host_listings_count    39307
# availability_365                  39307
# dtype: int64

# %% [markdown]
# **Filtering Rows And Columns Togethers**
# #**Methed is .loc*
# #**Method is .iloc*

# %%
df.loc[mask,['name','host_name']].head()
# Out:
#                                         name    host_name
# 3            Cozy Entire Floor of Brownstone  LisaRoxanne
# 5  Large Cozy 1 BR Apartment In Midtown East        Chris
# 7           Large Furnished Room Near B'way      Shunichi
# 8         Cozy Clean Guest Room - Family Apt    MaryEllen
# 9         Cute & Cozy Lower East Side 1 bdrm          Ben

# %%
df.loc[:,'name']
# Out:
# 0                       Clean & quiet apt home by the park
# 1                                    Skylit Midtown Castle
# 2                      THE VILLAGE OF HARLEM....NEW YORK !
# 3                          Cozy Entire Floor of Brownstone
# 4         Entire Apt: Spacious Studio/Loft by central park
#                                ...
# 48890      Charming one bedroom - newly renovated rowhouse
# 48891        Affordable room in Bushwick/East Williamsburg
# 48892              Sunny Studio at Historical Neighborhood
# 48893                 43rd St. Time Square-cozy single bed
# 48894    Trendy duplex in the very heart of Hell's Kitchen
# Name: name, Length: 48895, dtype: object

# %%
df.loc[mask,:].head(2)
# Out:
#      id                                       name  host_id    host_name  \
# 3  3831            Cozy Entire Floor of Brownstone     4869  LisaRoxanne
# 5  5099  Large Cozy 1 BR Apartment In Midtown East     7322        Chris
#
#   neighbourhood_group neighbourhood  latitude  longitude        room_type  \
# 3            Brooklyn  Clinton Hill  40.68514  -73.95976  Entire home/apt
# 5           Manhattan   Murray Hill  40.74767  -73.97500  Entire home/apt
#
#    price  minimum_nights  number_of_reviews last_review  reviews_per_month  \
# 3     89               1                270  2019-07-05               4.64
# 5    200               3                 74  2019-06-22               0.59
#
#    calculated_host_listings_count  availability_365
# 3                               1               194
# 5                               1               129

# %%
#Iloc exaples
df.iloc[0,1]
# Out:
# 'Clean & quiet apt home by the park'

# %%
df.iloc[1:5, 5:6]
# Out:
#   neighbourhood
# 1       Midtown
# 2        Harlem
# 3  Clinton Hill
# 4   East Harlem

# %% [markdown]
#  **Provide mask helper**

# %%
df.loc[df.price.between(100,500),'price'].head()
# Out:
# 0    149
# 1    225
# 2    150
# 5    200
# 9    150
# Name: price, dtype: int64

# %%
df.loc[df.price.isin([100,200]),'price'].head()
# Out:
# 5     200
# 54    200
# 63    200
# 76    200
# 94    100
# Name: price, dtype: int64

# %%
df == 'John'
# Out:
#           id   name  host_id  host_name  neighbourhood_group  neighbourhood  \
# 0      False  False    False       True                False          False
# 1      False  False    False      False                False          False
# 2      False  False    False      False                False          False
# 3      False  False    False      False                False          False
# 4      False  False    False      False                False          False
# ...      ...    ...      ...        ...                  ...            ...
# 48890  False  False    False      False                False          False
# 48891  False  False    False      False                False          False
# 48892  False  False    False      False                False          False
# 48893  False  False    False      False                False          False
# 48894  False  False    False      False                False          False
#
# ...

# %%
#Shows True if any columns contains Value 'John'
(df == 'John').any()

#(df== 'John').any(axis=1)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\ops\array_ops.py:253: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   res_values = method(rvalues)
# id                                False
# name                              False
# host_id                           False
# host_name                          True
# neighbourhood_group               False
# neighbourhood                     False
# latitude                          False
# longitude                         False
# room_type                         False
# price                             False
# minimum_nights                    False
# number_of_reviews                 False
# last_review                       False
# reviews_per_month                 False
# calculated_host_listings_count    False
# availability_365                  False
# dtype: bool

# %% [markdown]
# **Views Vs Copy**

# %%
df2 = df.copy()
df2['name'][0] = 'TESTING'
df2.head(1)
# Out:
# <ipython-input-78-f196b9ea384c>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['name'][0] = 'TESTING'
#      id     name  host_id host_name neighbourhood_group neighbourhood  \
# 0  2539  TESTING     2787      John            Brooklyn    Kensington
#
#    latitude  longitude     room_type  price  minimum_nights  \
# 0  40.64749  -73.97237  Private room    149               1
#
#    number_of_reviews last_review  reviews_per_month  \
# 0                  9  2018-10-19               0.21
#
#    calculated_host_listings_count  availability_365
# 0                               6               365

# %%
df2.loc[df2.index == 0, 'name'] = 'TESTING'
df2.head(1)
# Out:
#      id     name  host_id host_name neighbourhood_group neighbourhood  \
# 0  2539  TESTING     2787      John            Brooklyn    Kensington
#
#    latitude  longitude     room_type  price  minimum_nights  \
# 0  40.64749  -73.97237  Private room    149               1
#
#    number_of_reviews last_review  reviews_per_month  \
# 0                  9  2018-10-19               0.21
#
#    calculated_host_listings_count  availability_365
# 0                               6               365

# %%
df2[df2.host_name == 'John']['name'] ='Oh No'
df2.head(1)
# Out:
# <ipython-input-86-f80342e96f4e>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2[df2.host_name == 'John']['name'] ='Oh No'
#      id     name  host_id host_name neighbourhood_group neighbourhood  \
# 0  2539  TESTING     2787      John            Brooklyn    Kensington
#
#    latitude  longitude     room_type  price  minimum_nights  \
# 0  40.64749  -73.97237  Private room    149               1
#
#    number_of_reviews last_review  reviews_per_month  \
# 0                  9  2018-10-19               0.21
#
#    calculated_host_listings_count  availability_365
# 0                               6               365

# %% [markdown]
# ### Recap
# * .loc
# * .iloc
# * .between
# * .isin
# * .any
# * .all
# * .copy
# *  boolean oper &|^~
# *  view & copy

# %% [markdown]
# ### Basic of adding and removing Data

# %%
import pandas as pd

df = pd.read_csv('astronauts.csv')

# %%
df.head(1)
# Out:
#               Name    Year  Group  Status Birth Date    Birth Place Gender  \
# 0  Joseph M. Acaba  2004.0   19.0  Active  5/17/1967  Inglewood, CA   Male
#
#                                           Alma Mater Undergraduate Major  \
# 0  University of California-Santa Barbara; Univer...             Geology
#
#   Graduate Major Military Rank Military Branch  Space Flights  \
# 0        Geology           NaN             NaN              2
#
#    Space Flight (hr)  Space Walks  Space Walks (hr)  \
# 0               3307            2              13.0
#
#                                  Missions Death Date Death Mission
# 0  STS-119 (Discovery), ISS-31/32 (Soyuz)        NaN           NaN

# %% [markdown]
# ### Modifying type of columns
# Common for time series, categoricals, or converting string to numeric

# %%
birthdate = pd.to_datetime(df['Birth Date'],format='%m/%d/%Y')
birthdate
# Out:
# 0     1967-05-17
# 1     1936-03-07
# 2     1946-03-03
# 3     1951-05-20
# 4     1930-01-20
#          ...
# 352   1956-08-23
# 353   1962-07-26
# 354   1932-02-07
# 355   1930-09-24
# 356   1962-06-29
# Name: Birth Date, Length: 357, dtype: datetime64[ns]

# %%
birthdate.dt.year
# Out:
# 0      1967
# 1      1936
# 2      1946
# 3      1951
# 4      1930
#        ...
# 352    1956
# 353    1962
# 354    1932
# 355    1930
# 356    1962
# Name: Birth Date, Length: 357, dtype: int64

# %%
zarya = pd.to_datetime('1998-11-20')
df['age_at_zarya'] = (zarya - birthdate).astype('timedelta64[Y]')
df.head(2)
# Out:
#               Name    Year  Group   Status Birth Date    Birth Place Gender  \
# 0  Joseph M. Acaba  2004.0   19.0   Active  5/17/1967  Inglewood, CA   Male
# 1   Loren W. Acton     NaN    NaN  Retired   3/7/1936   Lewiston, MT   Male
#
#                                           Alma Mater  Undergraduate Major  \
# 0  University of California-Santa Barbara; Univer...              Geology
# 1   Montana State University; University of Colorado  Engineering Physics
#
#   Graduate Major  ... Military Branch Space Flights  Space Flight (hr)  \
# 0        Geology  ...             NaN             2               3307
# 1  Solar Physics  ...             NaN             1                190
#
#    Space Walks  Space Walks (hr)                                Missions  \
# 0            2              13.0  STS-119 (Discovery), ISS-31/32 (Soyuz)
# 1            0               0.0                   STS 51-F (Challenger)
#
#   Death Date Death Mission age_at_zarya      birth
# ...

# %%
df['birth'] = birthdate

# %%
df.head(2)
# Out:
#               Name    Year  Group   Status Birth Date    Birth Place Gender  \
# 0  Joseph M. Acaba  2004.0   19.0   Active  5/17/1967  Inglewood, CA   Male
# 1   Loren W. Acton     NaN    NaN  Retired   3/7/1936   Lewiston, MT   Male
#
#                                           Alma Mater  Undergraduate Major  \
# 0  University of California-Santa Barbara; Univer...              Geology
# 1   Montana State University; University of Colorado  Engineering Physics
#
#   Graduate Major  ... Military Branch Space Flights  Space Flight (hr)  \
# 0        Geology  ...             NaN             2               3307
# 1  Solar Physics  ...             NaN             1                190
#
#    Space Walks  Space Walks (hr)                                Missions  \
# 0            2              13.0  STS-119 (Discovery), ISS-31/32 (Soyuz)
# 1            0               0.0                   STS 51-F (Challenger)
#
#   Death Date Death Mission age_at_zarya      birth
# ...

# %% [markdown]
# ### Categoricals
# Why use? information can be utilised utilised by other libraries that pandas interfaces with, you can provie explicit sorting order rather thatn lexical order, and huge speed imporvements if you group on categories

# %%
df['Military Rank'].unique()
# Out:
# array([nan, 'Colonel', 'Lieutenant Colonel', 'Captain', 'Major General',
#        'Commander', 'Lieutenant Commander', 'Brigadier General', 'Major',
#        'Lieutenant General', 'Chief Warrant Officer', 'Rear Admiral',
#        'Vice Admiral'], dtype=object)

# %%
df['Military Rank'].dtype
# Out:
# dtype('O')

# %%
#Change Datatype to chategor
df['Military Rank'] = df['Military Rank'].astype('category')
df['Military Rank'].dtype
# Out:
# CategoricalDtype(categories=['Brigadier General', 'Captain', 'Chief Warrant Officer',
#                   'Colonel', 'Commander', 'Lieutenant Colonel',
#                   'Lieutenant Commander', 'Lieutenant General', 'Major',
#                   'Major General', 'Rear Admiral', 'Vice Admiral'],
#                  ordered=False)

# %%
#second ways
pd.Categorical(df['Military Rank'])
# Out:
# [NaN, NaN, Colonel, Colonel, Colonel, ..., NaN, Commander, Colonel, Captain, Colonel]
# Length: 357
# Categories (12, object): [Brigadier General, Captain, Chief Warrant Officer, Colonel, ..., Major, Major General, Rear Admiral, Vice Admiral]

# %% [markdown]
# ### Numerica And String Conversation

# %%
df.head(1)
# Out:
#               Name    Year  Group  Status Birth Date    Birth Place Gender  \
# 0  Joseph M. Acaba  2004.0   19.0  Active  5/17/1967  Inglewood, CA   Male
#
#                                           Alma Mater Undergraduate Major  \
# 0  University of California-Santa Barbara; Univer...             Geology
#
#   Graduate Major  ... Military Branch Space Flights  Space Flight (hr)  \
# 0        Geology  ...             NaN             2               3307
#
#    Space Walks  Space Walks (hr)                                Missions  \
# 0            2              13.0  STS-119 (Discovery), ISS-31/32 (Soyuz)
#
#   Death Date Death Mission age_at_zarya      birth
# 0        NaN           NaN         31.0 1967-05-17
#
# [1 rows x 21 columns]

# %%
df.age_at_zarya.astype('str').astype('float').astype('int')[0]
# Out:
# 31

# %% [markdown]
# ### Removing Columns And Rows

# %%
#Creating dummy dataframe for operations
df2 = df[['Name','Year','Group']].copy()
df2.head(2)
# Out:
#               Name    Year  Group
# 0  Joseph M. Acaba  2004.0   19.0
# 1   Loren W. Acton     NaN    NaN

# %%
#removing
df2.drop('Group',axis=1).head()
# Out:
#                Name    Year
# 0   Joseph M. Acaba  2004.0
# 1    Loren W. Acton     NaN
# 2  James C. Adamson  1984.0
# 3   Thomas D. Akers  1987.0
# 4       Buzz Aldrin  1963.0

# %%
df2.drop(1).head()
# Out:
#                Name    Year  Group
# 0   Joseph M. Acaba  2004.0   19.0
# 2  James C. Adamson  1984.0   10.0
# 3   Thomas D. Akers  1987.0   12.0
# 4       Buzz Aldrin  1963.0    3.0
# 5   Andrew M. Allen  1987.0   12.0

# %%
df2.drop(columns='Group').head()
# Out:
#                Name    Year
# 0   Joseph M. Acaba  2004.0
# 1    Loren W. Acton     NaN
# 2  James C. Adamson  1984.0
# 3   Thomas D. Akers  1987.0
# 4       Buzz Aldrin  1963.0

# %%
df2.drop(columns=['Year','Name']).head()
# Out:
#    Group
# 0   19.0
# 1    NaN
# 2   10.0
# 3   12.0
# 4    3.0

# %% [markdown]
# ### Adding rows

# %%
df2.append({"Name":"Sonu","Year":2010,"Group":20.0},ignore_index=True)
# Out:
#                       Name    Year  Group
# 0          Joseph M. Acaba  2004.0   19.0
# 1           Loren W. Acton     NaN    NaN
# 2         James C. Adamson  1984.0   10.0
# 3          Thomas D. Akers  1987.0   12.0
# 4              Buzz Aldrin  1963.0    3.0
# ..                     ...     ...    ...
# 353  Neil W. Woodward III   1998.0   17.0
# 354       Alfred M. Worden  1966.0    5.0
# 355          John W. Young  1962.0    2.0
# 356        George D. Zamka  1998.0   17.0
# 357                   Sonu  2010.0   20.0
#
# [358 rows x 3 columns]

# %%
df_sis = pd.DataFrame({"Name":['Didi'],"Year":[2019],"Group":[15.0]})
df_sis
# Out:
#    Name  Year  Group
# 0  Didi  2019   15.0

# %%
df2.append(df_sis,ignore_index=True)
# Out:
#                       Name    Year  Group
# 0          Joseph M. Acaba  2004.0   19.0
# 1           Loren W. Acton     NaN    NaN
# 2         James C. Adamson  1984.0   10.0
# 3          Thomas D. Akers  1987.0   12.0
# 4              Buzz Aldrin  1963.0    3.0
# ..                     ...     ...    ...
# 353  Neil W. Woodward III   1998.0   17.0
# 354       Alfred M. Worden  1966.0    5.0
# 355          John W. Young  1962.0    2.0
# 356        George D. Zamka  1998.0   17.0
# 357                   Didi  2019.0   15.0
#
# [358 rows x 3 columns]

# %% [markdown]
# ### Adding Columns

# %%
#Way 1
df2['Col1'] = 'Sonu'
df2.head()
# Out:
#                Name    Year  Group  Col1
# 0   Joseph M. Acaba  2004.0   19.0  Sonu
# 1    Loren W. Acton     NaN    NaN  Sonu
# 2  James C. Adamson  1984.0   10.0  Sonu
# 3   Thomas D. Akers  1987.0   12.0  Sonu
# 4       Buzz Aldrin  1963.0    3.0  Sonu

# %%
#Way 2
df2.assign(col2='Shaikh').head()
# Out:
#                Name    Year  Group  Col1    col2
# 0   Joseph M. Acaba  2004.0   19.0  Sonu  Shaikh
# 1    Loren W. Acton     NaN    NaN  Sonu  Shaikh
# 2  James C. Adamson  1984.0   10.0  Sonu  Shaikh
# 3   Thomas D. Akers  1987.0   12.0  Sonu  Shaikh
# 4       Buzz Aldrin  1963.0    3.0  Sonu  Shaikh

# %%
#Way 3
df2.insert(0,'FirstName',df2.Name.str.split(' ',1,expand=True)[0])
df2.head()
# Out:
#   FirstName              Name    Year  Group  Col1
# 0    Joseph   Joseph M. Acaba  2004.0   19.0  Sonu
# 1     Loren    Loren W. Acton     NaN    NaN  Sonu
# 2     James  James C. Adamson  1984.0   10.0  Sonu
# 3    Thomas   Thomas D. Akers  1987.0   12.0  Sonu
# 4      Buzz       Buzz Aldrin  1963.0    3.0  Sonu

# %% [markdown]
# ### Transpose Rows to Columns & columns to Rows

# %%
df3 = df.set_index('Name')
df3.head(2)
# Out:
#                    Year  Group   Status Birth Date    Birth Place Gender  \
# Name
# Joseph M. Acaba  2004.0   19.0   Active  5/17/1967  Inglewood, CA   Male
# Loren W. Acton      NaN    NaN  Retired   3/7/1936   Lewiston, MT   Male
#
#                                                         Alma Mater  \
# Name
# Joseph M. Acaba  University of California-Santa Barbara; Univer...
# Loren W. Acton    Montana State University; University of Colorado
#
#                  Undergraduate Major Graduate Major Military Rank  \
# Name
# Joseph M. Acaba              Geology        Geology           NaN
# Loren W. Acton   Engineering Physics  Solar Physics           NaN
#
#                 Military Branch  Space Flights  Space Flight (hr)  \
# Name
# Joseph M. Acaba             NaN              2               3307
# Loren W. Acton              NaN              1                190
#
#                  Space Walks  Space Walks (hr)  \
# Name
# Joseph M. Acaba            2              13.0
# ...

# %%
df3.T.head(2)
# Out:
# Name  Joseph M. Acaba Loren W. Acton James C. Adamson Thomas D. Akers  \
# Year             2004            NaN             1984            1987
# Group              19            NaN               10              12
#
# Name  Buzz Aldrin Andrew M. Allen Joseph P. Allen Scott D. Altman  \
# Year         1963            1987            1967            1995
# Group           3              12               6              15
#
# Name  William A. Anders Clayton C. Anderson  ... Sunita L. Williams  \
# Year               1963                1998  ...               1998
# Group                 3                  17  ...                 17
#
# Name  Barry E. Wilmore Stephanie D. Wilson G. Reid Wiseman Peter J. K. Wisoff  \
# Year              2000                1996            2009               1990
# Group               18                  16              20                 13
#
# Name  David A. Wolf Neil W. Woodward III  Alfred M. Worden John W. Young  \
# ...

# %% [markdown]
# ### Recap
# * df['newcol'] = val
# * dtypes
# * astype
# * drop
# * append
# * assign
# * T

# %% [markdown]
# ### Basic of Apply, Map and Vectorised function

# %%
import numpy as np
import pandas as pd

# %%
data = np.round(np.random.normal(size=(4,3)),2)
data
# Out:
# array([[-1.28, -2.56,  0.29],
#        [-0.43, -0.32,  1.26],
#        [-0.49, -0.19,  0.3 ],
#        [ 0.96,  1.51, -0.01]])

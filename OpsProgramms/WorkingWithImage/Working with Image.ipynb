# %%
#import libraries
from PIL import Image

# %%
mac = Image.open('example.jpg')

# %%
mac
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1993x1257 at 0x20B1053C8B0>

# %%
mac.size
# Out:
# (1993, 1257)

# %%
mac.filename
# Out:
# 'example.jpg'

# %%
mac.format
# Out:
# 'JPEG'

# %%
mac.format_description
# Out:
# 'JPEG (ISO 10918)'

# %% [markdown]
# #### Cropping The Image

# %%
mac.crop((0,0,350,150))
# Out:
# <PIL.Image.Image image mode=RGB size=350x150 at 0x20B13C0ED30>

# %%
halfway = 1993/2
x = halfway - 200
w = halfway + 200

y = 800
h = 1257

box = (x,y,w,h)

# %%
mac.crop(box)
# Out:
# <PIL.Image.Image image mode=RGB size=400x457 at 0x20B13BEC760>

# %%
computer = mac.crop(box)
mac.paste(im=computer,box=(0,0))
mac.paste(im=computer,box=(400,457))
mac
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1993x1257 at 0x20B1053C8B0>

# %%
pencile = Image.open('pencils.jpg')

# %%
pencile.size
# Out:
# (1950, 1300)

# %%
# top 3 pencils

x = 0
y = 0

w = 1950 / 3
h = 1300 / 9

pencile.crop((x,y,w,h))
# Out:
# <PIL.Image.Image image mode=RGB size=650x144 at 0x20B136EF8B0>

# %%
# Bottom 3 Pencils

x = 0
y = 1150
w = 1950 / 3
h = 1300

pencile.crop((x,y,w,h))
# Out:
# <PIL.Image.Image image mode=RGB size=650x150 at 0x20B13E296A0>

# %%
#Resize Image
mac.resize((3000,500))
# Out:
# <PIL.Image.Image image mode=RGB size=3000x500 at 0x20B106F4F70>

# %%
#Rotate Images
mac.rotate(180)
# Out:
# <PIL.Image.Image image mode=RGB size=1993x1257 at 0x20B136EFF40>

# %% [markdown]
# #### Color Transparency
#
# __RGBA - Red, Green, Blue, Alph__

# %%
blue = Image.open('blue_color.png')

# %%
blue
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=P size=200x200 at 0x20B137B69D0>

# %%
red = Image.open('red_color.jpg')

# %%
red
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=200x200 at 0x20B13C28400>

# %%
red.putalpha(int(255/2))
red
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGBA size=200x200 at 0x20B13C28400>

# %%
red.paste(im=blue,box=(0,0))

# %%
red
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGBA size=200x200 at 0x20B13C28400>

# %%
red.save('black.png')

# %%
black = Image.open('black.png')

# %%
black
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=200x200 at 0x20B13E54D00>

# %%
def roll(image, delta):
    """Roll an image sideways."""
    xsize, ysize = image.size

    delta = delta % xsize
    if delta == 0: return image

    part1 = image.crop((0, 0, delta, ysize))
    part2 = image.crop((delta, 0, xsize, ysize))
    image.paste(part1, (xsize-delta, 0, xsize, ysize))
    image.paste(part2, (0, 0, xsize-delta, ysize))

    return image

# %%
#roll(mac,1)

# %% [markdown]
# #### Excercise

# %%
from PIL import Image

# %%
mask = Image.open('mask.png')
word = Image.open('word_matrix.png')

# %%
mask
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=505x251 at 0x20B13C0EDC0>

# %%
word
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1015x559 at 0x20B13E8C550>

# %%
print(mask.size)
print(word.size)
# Out:
# (505, 251)
# (1015, 559)

# %%
mask = mask.resize((1015,559))

# %%
print(mask.size)
print(word_matrix.size)
# Out:
# (1015, 559)
# (1015, 559)

# %%
mask.putalpha(200)

# %%
mask
# Out:
# <PIL.Image.Image image mode=RGBA size=1015x559 at 0x20B13E36070>

# %%
word.paste(mask,(0,0),mask)

# %%
word
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1015x559 at 0x20B13E8C550>

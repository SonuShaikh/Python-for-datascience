# %%
import pandas as pd

# %%
#Import Data Way 1
stat = pd.read_csv('D:\\Financial Sample.csv')

# %%
#importing data from current working directory
stat = pd.read_csv('Financial Sample.csv')

# %%
#2.print len of datafram
len(stat)
# Out:
# 700

# %%
#3. print the columns
print(stat1.columns)
# Out:
# Index(['Segment', 'Country', ' Product ', ' DiscountBand ', 'UnitsSold',
#        ' ManufacturingPrice ', ' SalePrice ', ' GrossSales ', ' Discounts ',
#        '  Sales ', ' COGS ', ' Profit ', 'Date', 'MonthNumber', ' MonthName ',
#        'Year'],
#       dtype='object')

# %%
#4 print the number of colu
print(len(stat1.columns))
# Out:
# 16

# %%
#5 print top rows
stat.head(6)
# Out:
#   PlayerName  MatchePlayed  Sessions  AnnualSalary
# 0       Sonu           150      2014         30000
# 1      Pappu           202      2015         70000
# 2       Papa           254      2016         80000
# 3      Mummy           306      2017          9000

# %%
#print bottom rows
stat1.tail(6)
# Out:
#               Segment                   Country    Product   Discount Band   \
# 694        Government                    France        VTT            High
# 695    Small Business                    France   Amarilla            High
# 696    Small Business                    Mexico   Amarilla            High
# 697        Government                    Mexico    Montana            High
# 698        Government                    Canada      Paseo            High
# 699  Channel Partners  United States of America        VTT            High
#
#      Units Sold  Manufacturing Price   Sale Price    Gross Sales   \
# 694       293.0              $250.00       $20.00      $5,860.00
# 695      2475.0              $260.00      $300.00    $742,500.00
# 696       546.0              $260.00      $300.00    $163,800.00
# 697      1368.0                $5.00        $7.00      $9,576.00
# 698       723.0               $10.00        $7.00      $5,061.00
# ...

# %%
#print column inforamtion 
stat1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 700 entries, 0 to 699
# Data columns (total 16 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Segment                700 non-null    object
#  1   Country                700 non-null    object
#  2    Product               700 non-null    object
#  3    Discount Band         700 non-null    object
#  4   Units Sold             700 non-null    float64
#  5    Manufacturing Price   700 non-null    object
#  6    Sale Price            700 non-null    object
#  7    Gross Sales           700 non-null    object
#  8    Discounts             700 non-null    object
#  9     Sales                700 non-null    object
#  10   COGS                  700 non-null    object
#  11   Profit                700 non-null    object
#  12  Date                   700 non-null    object
#  13  Month Number           700 non-null    int64
# ...

# %%
#Get stats on columns
stat1 = stat1.describe()

# %%
#Transpos data
stat1.describe().transpose()
# Out:
#               count         mean         std     min      25%     50%  \
# Units Sold    700.0  1608.294286  867.427859   200.0   905.00  1542.5
# Month Number  700.0     7.900000    3.377321     1.0     5.75     9.0
# Year          700.0  2013.750000    0.433322  2013.0  2013.75  2014.0
#
#                    75%     max
# Units Sold    2229.125  4492.5
# Month Number    10.250    12.0
# Year          2014.000  2014.0

# %%
### Renaming datafram and columns

# %%
stat.columns = ['Segment', 'Country', ' Product ', ' DiscountBand ', 'UnitsSold',
       ' ManufacturingPrice ', ' SalePrice ', ' GrossSales ', ' Discounts ',
       '  Sales ', ' COGS ', ' Profit ', 'Date', 'MonthNumber',
       ' MonthName ', 'Year']

# %%
#Updated column names
stat1.head()
# Out:
#       Segment  Country     Product   DiscountBand   UnitsSold  \
# 0  Government   Canada   Carretera           None      1618.5
# 1  Government  Germany   Carretera           None      1321.0
# 2   Midmarket   France   Carretera           None      2178.0
# 3   Midmarket  Germany   Carretera           None       888.0
# 4   Midmarket   Mexico   Carretera           None      2470.0
#
#    ManufacturingPrice   SalePrice    GrossSales   Discounts         Sales   \
# 0               $3.00      $20.00    $32,370.00        $-      $32,370.00
# 1               $3.00      $20.00    $26,420.00        $-      $26,420.00
# 2               $3.00      $15.00    $32,670.00        $-      $32,670.00
# 3               $3.00      $15.00    $13,320.00        $-      $13,320.00
# 4               $3.00      $15.00    $37,050.00        $-      $37,050.00
#
#           COGS        Profit       Date  MonthNumber  MonthName   Year
# 0   $16,185.00    $16,185.00   1/1/2014            1    January   2014
# ...

# %%
## Subsetting the dataframs in Pnads
## There are three parts
# 1. Rows
# 2. Columns
# 3. Combine Boths

# %%
# Rows
stat[100:105]
# Out:
#               Segment                   Country     Product   Discount Band   \
# 100    Small Business                   Germany   Carretera             Low
# 101        Government                    France   Carretera             Low
# 102        Government                    Canada   Carretera             Low
# 103  Channel Partners  United States of America     Montana             Low
# 104        Government  United States of America     Montana             Low
#
#      Units Sold  Manufacturing Price   Sale Price    Gross Sales   \
# 100       214.0                $3.00      $300.00     $64,200.00
# 101      2145.0                $3.00        $7.00     $15,015.00
# 102      2852.0                $3.00      $350.00    $998,200.00
# 103      1142.0                $5.00       $12.00     $13,704.00
# 104      1566.0                $5.00       $20.00     $31,320.00
#
#        Discounts          Sales           COGS         Profit        Date  \
# ...

# %%
#Quick Excercise Reverse Datafram
stat[100:50:-1]
# Out:
#               Segment                   Country     Product   Discount Band   \
# 100    Small Business                   Germany   Carretera             Low
# 99   Channel Partners                    Canada   Carretera             Low
# 98         Enterprise                    Canada   Carretera             Low
# 97          Midmarket                    France    Amarilla             Low
# 96   Channel Partners  United States of America    Amarilla             Low
# 95         Enterprise                    France         VTT             Low
# 94         Government                    Mexico         VTT             Low
# 93     Small Business                    Mexico         VTT             Low
# 92     Small Business                   Germany         VTT             Low
# 91         Enterprise                    France         VTT             Low
# 90         Enterprise  United States of America         VTT             Low
# ...

# %%
#Get every 90th row
stat[::90]
# Out:
#         Segment                   Country     Product   Discount Band   \
# 0    Government                    Canada   Carretera            None
# 90   Enterprise  United States of America         VTT             Low
# 180  Government                    Canada   Carretera             Low
# 270  Government                    Canada    Amarilla          Medium
# 360  Government  United States of America    Amarilla          Medium
# 450  Government                    France         VTT          Medium
# 540   Midmarket  United States of America     Montana            High
# 630   Midmarket                    Canada   Carretera            High
#
#      Units Sold  Manufacturing Price   Sale Price    Gross Sales   \
# 0        1618.5                $3.00       $20.00     $32,370.00
# 90        727.0              $250.00      $125.00     $90,875.00
# 180      2851.0                $3.00        $7.00     $19,957.00
# 270      1228.0              $260.00      $350.00    $429,800.00
# ...

# %%
stat[['Country','Segment']].head()
# Out:
#    Country     Segment
# 0   Canada  Government
# 1  Germany  Government
# 2   France   Midmarket
# 3  Germany   Midmarket
# 4   Mexico   Midmarket

# %%
stat.Segment.head()
# Out:
# 0    Government
# 1    Government
# 2     Midmarket
# 3     Midmarket
# 4     Midmarket
# Name: Segment, dtype: object

# %%
#Combine
stat[2:9][['Country','Segment']]
# Out:
#    Country           Segment
# 2   France         Midmarket
# 3  Germany         Midmarket
# 4   Mexico         Midmarket
# 5  Germany        Government
# 6  Germany         Midmarket
# 7   Canada  Channel Partners
# 8   France        Government

# %%
#Basic operation on Data fram
#Additions
result = stat.MatchePlayed + stat.AnnualSalary
# Out:
# 0    30150
# 1    70202
# 2    80254
# 3     9306
# dtype: int64

# %%
PerMatchIncome = stat.AnnualSalary /stat.MatchePlayed

# %%
#Add Column
stat['PerMatchIncome'] = stat.AnnualSalary /stat.MatchePlayed

# %%
stat
# Out:
#   PlayerName  MatchePlayed  Sessions  AnnualSalary  PerMatchIncome
# 0       Sonu           150      2014         30000      200.000000
# 1      Pappu           202      2015         70000      346.534653
# 2       Papa           254      2016         80000      314.960630
# 3      Mummy           306      2017          9000       29.411765

# %%
#Remove Column
stat.drop('PerMatchIncome',1)
# Out:
#   PlayerName  MatchePlayed  Sessions  AnnualSalary
# 0       Sonu           150      2014         30000
# 1      Pappu           202      2015         70000
# 2       Papa           254      2016         80000
# 3      Mummy           306      2017          9000

# %%
stat = stat.drop('PerMatchIncome',1)
stat
# Out:
#   PlayerName  MatchePlayed  Sessions  AnnualSalary
# 0       Sonu           150      2014         30000
# 1      Pappu           202      2015         70000
# 2       Papa           254      2016         80000
# 3      Mummy           306      2017          9000

# %%
#Filtering
filterObj = stat1.UnitsSold > 1000
filterObj
# Out:
# count    False
# mean      True
# std      False
# min      False
# 25%      False
# 50%       True
# 75%       True
# max       True
# Name: UnitsSold, dtype: bool

# %%
stat1[filterObj]
# Out:
#         UnitsSold  MonthNumber     Year
# mean  1608.294286         7.90  2013.75
# 50%   1542.500000         9.00  2014.00
# 75%   2229.125000        10.25  2014.00
# max   4492.500000        12.00  2014.00

# %%
#Example 2
filterObj2 = stat1.MonthNumber > 5

# %%
stat1[filterObj]
# Out:
#         UnitsSold  MonthNumber     Year
# mean  1608.294286         7.90  2013.75
# 50%   1542.500000         9.00  2014.00
# 75%   2229.125000        10.25  2014.00
# max   4492.500000        12.00  2014.00

# %%
stat1[filterObj  & filterObj2]
# Out:
#         UnitsSold  MonthNumber     Year
# mean  1608.294286         7.90  2013.75
# 50%   1542.500000         9.00  2014.00
# 75%   2229.125000        10.25  2014.00
# max   4492.500000        12.00  2014.00

# %%
stat1
# Out:
#          UnitsSold  MonthNumber         Year
# count   700.000000   700.000000   700.000000
# mean   1608.294286     7.900000  2013.750000
# std     867.427859     3.377321     0.433322
# min     200.000000     1.000000  2013.000000
# 25%     905.000000     5.750000  2013.750000
# 50%    1542.500000     9.000000  2014.000000
# 75%    2229.125000    10.250000  2014.000000
# max    4492.500000    12.000000  2014.000000

# %%
stat1[stat1.Year == 2013]
# Out:
#      UnitsSold  MonthNumber    Year
# min      200.0          1.0  2013.0
